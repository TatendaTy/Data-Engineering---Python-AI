# %% [markdown]
# # API's as a Data Source

# %%
# API's for batch extraction
# 1. Call an API at scheduled intervals (e.g every hour or day)
# 2. Retrieve all availbale data (e.g last 24 hours of records)
# 3. Store results in a database, data warehouse or file system

# %%
import requests
import json

def fetch_batch_data():
    url = "https://api.example.com/daily_reports"
    response = requests.get(url)
    data = response.json()

    with open('daily_reports.json', 'w') as file:
        json.dump(data, file, indent=4)

fetch_batch_data()

# %%
import requests

url = 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events'

response = requests.get(url)
print(response.json())
# Out:
# [{'id': '52602815580', 'type': 'WatchEvent', 'actor': {'id': 66147771, 'login': 'HephWisdom', 'display_login': 'HephWisdom', 'gravatar_id': '', 'url': 'https://api.github.com/users/HephWisdom', 'avatar_url': 'https://avatars.githubusercontent.com/u/66147771?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-28T00:36:16Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52601462680', 'type': 'ForkEvent', 'actor': {'id': 33403958, 'login': 'singh3ss', 'display_login': 'singh3ss', 'gravatar_id': '', 'url': 'https://api.github.com/users/singh3ss', 'avatar_url': 'https://avatars.githubusercontent.com/u/33403958?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1027381327, 'node_id': 'R_kgDOPTyYTw', 'name': 'data-engineering-zoomcamp2025COPY', 'full_name': 'singh3ss/data-engineering-zoomcamp2025COPY', 'private': False, 'owner': {'login': 'singh3ss', 'id': 33403958, 'node_id': 'MDQ6VXNlcjMzNDAzOTU4', 'avatar_url': 'https://avatars.githubusercontent.com/u/33403958?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/singh3ss', 'html_url': 'https://github.com/singh3ss', 'followers_url': 'https://api.github.com/users/singh3ss/followers', 'following_url': 'https://api.github.com/users/singh3ss/following{/other_user}', 'gists_url': 'https://api.github.com/users/singh3ss/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/singh3ss/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/singh3ss/subscriptions', 'organizations_url': 'https://api.github.com/users/singh3ss/orgs', 'repos_url': 'https://api.github.com/users/singh3ss/repos', 'events_url': 'https://api.github.com/users/singh3ss/events{/privacy}', 'received_events_url': 'https://api.github.com/users/singh3ss/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/singh3ss/data-engineering-zoomcamp2025COPY', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY', 'forks_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/forks', 'keys_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/teams', 'hooks_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/hooks', 'issue_events_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/issues/events{/number}', 'events_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/events', 'assignees_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/assignees{/user}', 'branches_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/branches{/branch}', 'tags_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/tags', 'blobs_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp20 ...

# %% [markdown]
# #### APIs for streaming data extraction
#
# - there are API's that allow you to extract data in real-time or near real-time. this method is used for systems that require continuous data updates, such as social media feeds, financial market data, or IoT sensor data.
#
# #### Common streaming API examples:
# - Webhooks (Stripe, Github, Slack) - Real-time event notifications
# - Social Media APIs (Twitter, Facebook) - Real-time posts and interactions
# - Financial Market APIs (Alpha Vantage, IEX Cloud) - Real-time stock prices and trading data
#
# #### How the streaming API extraction works:
# 1. API sends real-time updates as data changes
# 2. A webhook  or WebSocket listens for events
# 3. Data is processed immediately as it arrives instead of being stored in bulk

# %%
import websocket

def on_message(ws, message):
    print("Received message:", message)

ws = websocket.WebSocketApp("wss://api.example.com/stream", on_message=on_message)
ws.run_forever()

# %%
# Common challenges
import time
# 1. Rate Limiting
# 'requests' is already imported in a previous cell, so we can use it directly
url = 'https://api.github.com/rate_limit'
requests.get(url).json()

# sleep for some time to avoid hitting rate limits
remaining_requests = requests.get(url).json()['rate']['remaining']

if remaining_requests == 0:
    time.sleep(60)
# Out:
# {'resources': {'core': {'limit': 60,
#    'remaining': 56,
#    'reset': 1753672125,
#    'used': 4,
#    'resource': 'core'},
#   'graphql': {'limit': 0,
#    'remaining': 0,
#    'reset': 1753672459,
#    'used': 0,
#    'resource': 'graphql'},
#   'integration_manifest': {'limit': 5000,
#    'remaining': 5000,
#    'reset': 1753672459,
#    'used': 0,
#    'resource': 'integration_manifest'},
#   'search': {'limit': 10,
#    'remaining': 10,
#    'reset': 1753668919,
#    'used': 0,
#    'resource': 'search'}},
#  'rate': {'limit': 60,
#   'remaining': 56,
#   'reset': 1753672125,
#   'used': 4,
#   'resource': 'core'}}

# %%
# 2. Authentication
# Most APIs require an API key or token to access data securely. Without authentication, requests may be denied or limited.

# Types of Authentication:
# 1. API Keys - Simple key provided by the API provider, included in request headers or parameters.
# 2. OAuth tokens- More secure, allows users to authorize access without sharing credentials.
# 3. Basic Authentication - Username and password encoded in the request header.(less common)

# Example of using an API key in a request
import os
from dotenv import load_dotenv

load_dotenv()
GITHUB_ACCESS_TOKEN = os.getenv("GITHUB_ACCESS_TOKEN")

headers = {
    'Authorization': f'token {GITHUB_ACCESS_TOKEN}',
}

url = 'https://api.github.com/user'
requests.get(url, headers=headers).json()
# Out:
# {'login': 'TatendaTy',
#  'id': 46075417,
#  'node_id': 'MDQ6VXNlcjQ2MDc1NDE3',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/46075417?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/TatendaTy',
#  'html_url': 'https://github.com/TatendaTy',
#  'followers_url': 'https://api.github.com/users/TatendaTy/followers',
#  'following_url': 'https://api.github.com/users/TatendaTy/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/TatendaTy/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/TatendaTy/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/TatendaTy/subscriptions',
#  'organizations_url': 'https://api.github.com/users/TatendaTy/orgs',
#  'repos_url': 'https://api.github.com/users/TatendaTy/repos',
#  'events_url': 'https://api.github.com/users/TatendaTy/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/TatendaTy/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
#  'site_admin': False,
#  'name': 'Tatenda Kabanda',
#  'company': 'USIU-A',
#  'blog': '',
#  'location': 'Nairobi',
#  'email': None,
#  'hireable': True,
#  'bio': "I'm a dynamic and passionate tech enthusiast with a keen interest in programming and solving challenges using Python.",
#  'twitter_username': None,
#  'notification_email': None,
#  'public_repos': 25,
#  'public_gists': 0,
#  'followers': 6,
#  'following': 17,
#  'created_at': '2018-12-22T20:47:42Z',
#  'updated_at': '2025-07-26T11:47:01Z'}

# %%
# 3. Pagination
# Many APIs return data in pages to limit the amount of data sent in a single response. 
# You may need to handle pagination to retrieve all available data.

# Example of handling pagination
url = 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events'

response = requests.get(url)
response


# what the above does
# 1. Starts at page 1 and makes a GET request to the API endpoint.
# 2. Retrieves JSON data from the response.
# 3. Checks if there are more pages by looking for a 'next' link in the response headers.
# 4. If there is a 'next' link,it updates BASE_URL and makes requests until all pages are retrieved.
# NB different API's handle pagination differently (such as offsets, cursors, page numbers, or tokens instead of links), so there's need to adjust the code based on the API's documentation.
# Out:
# <Response [200]>

# %%
url = 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events'

while True:
    response = requests.get(url)
    data = response.json()
    print(len(data), "events retrieved")

    if 'next' not in response.links:
        break

    url = response.links['next']['url']
# Out:
# 30 events retrieved
# 30 events retrieved
# 30 events retrieved
# 30 events retrieved
# 30 events retrieved
# 30 events retrieved
# 30 events retrieved
# 30 events retrieved
# 30 events retrieved
# 27 events retrieved

# %%
# 4. Avoiding memory issues while extracting
# to prevent the pipeline from crashing, control memory usage
# Challenges with memory
# 1. many pipelines run on systems with limited memory, i.e serverless functions or shared clusters
# 2. loading all the data into memory at once can lead to memory errors or slow performance

# %%
# Solution for batch processing/streaming data
# Here streaming means that data is processed in smaller chunks or batches, rather than loading everything into memory at once. This approach helps to manage memory usage and allows for processing large datasets efficiently.
# Use streaming to transfer data between buffers, such as:
# 1. from API's to local files
# 2. from webhooks to event queries
# 3. from event queries(like Kafka) to storage buckets

def events_getter():
    url = 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events'
    
    while True:
        response = requests.get(url)
        data = response.json()
        yield data
        
        if 'next' not in response.links:
            break
        
        url = response.links['next']['url']

# %%
events_pages = events_getter()

for events_page in events_pages:
    # Process each page of events
    # print(len(events_getter), "events retrieved")
    # Here you can save the events to a file or database, or process them as needed
    # For example, you could write them to a JSON file:
    # with open('events.json', 'a') as f:
    #     json.dump(events_getter, f)
    #     f.write('\n')  # Write each page on a new line
    # use this for now
    print(events_page)  # Print or process the events as needed
# Out:
# [{'id': '52602815580', 'type': 'WatchEvent', 'actor': {'id': 66147771, 'login': 'HephWisdom', 'display_login': 'HephWisdom', 'gravatar_id': '', 'url': 'https://api.github.com/users/HephWisdom', 'avatar_url': 'https://avatars.githubusercontent.com/u/66147771?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-28T00:36:16Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52601462680', 'type': 'ForkEvent', 'actor': {'id': 33403958, 'login': 'singh3ss', 'display_login': 'singh3ss', 'gravatar_id': '', 'url': 'https://api.github.com/users/singh3ss', 'avatar_url': 'https://avatars.githubusercontent.com/u/33403958?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1027381327, 'node_id': 'R_kgDOPTyYTw', 'name': 'data-engineering-zoomcamp2025COPY', 'full_name': 'singh3ss/data-engineering-zoomcamp2025COPY', 'private': False, 'owner': {'login': 'singh3ss', 'id': 33403958, 'node_id': 'MDQ6VXNlcjMzNDAzOTU4', 'avatar_url': 'https://avatars.githubusercontent.com/u/33403958?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/singh3ss', 'html_url': 'https://github.com/singh3ss', 'followers_url': 'https://api.github.com/users/singh3ss/followers', 'following_url': 'https://api.github.com/users/singh3ss/following{/other_user}', 'gists_url': 'https://api.github.com/users/singh3ss/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/singh3ss/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/singh3ss/subscriptions', 'organizations_url': 'https://api.github.com/users/singh3ss/orgs', 'repos_url': 'https://api.github.com/users/singh3ss/repos', 'events_url': 'https://api.github.com/users/singh3ss/events{/privacy}', 'received_events_url': 'https://api.github.com/users/singh3ss/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/singh3ss/data-engineering-zoomcamp2025COPY', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY', 'forks_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/forks', 'keys_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/teams', 'hooks_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/hooks', 'issue_events_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/issues/events{/number}', 'events_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/events', 'assignees_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/assignees{/user}', 'branches_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/branches{/branch}', 'tags_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/tags', 'blobs_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp2025COPY/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/singh3ss/data-engineering-zoomcamp20 ...
# [{'id': '52578100164', 'type': 'WatchEvent', 'actor': {'id': 205520946, 'login': 'mrtsekr', 'display_login': 'mrtsekr', 'gravatar_id': '', 'url': 'https://api.github.com/users/mrtsekr', 'avatar_url': 'https://avatars.githubusercontent.com/u/205520946?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-26T14:59:12Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52577453740', 'type': 'WatchEvent', 'actor': {'id': 967952, 'login': 'ghalenir', 'display_login': 'ghalenir', 'gravatar_id': '', 'url': 'https://api.github.com/users/ghalenir', 'avatar_url': 'https://avatars.githubusercontent.com/u/967952?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-26T14:13:16Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52576249092', 'type': 'WatchEvent', 'actor': {'id': 207148558, 'login': 'Alexis-3579', 'display_login': 'Alexis-3579', 'gravatar_id': '', 'url': 'https://api.github.com/users/Alexis-3579', 'avatar_url': 'https://avatars.githubusercontent.com/u/207148558?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-26T12:50:28Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52575993103', 'type': 'WatchEvent', 'actor': {'id': 8923873, 'login': 'silviosisa', 'display_login': 'silviosisa', 'gravatar_id': '', 'url': 'https://api.github.com/users/silviosisa', 'avatar_url': 'https://avatars.githubusercontent.com/u/8923873?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-26T12:32:58Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52575829757', 'type': 'WatchEvent', 'actor': {'id': 218163569, 'login': 'id10tcode', 'display_login': 'id10tcode', 'gravatar_id': '', 'url': 'https://api.github.com/users/id10tcode', 'avatar_url': 'https://avatars.githubusercontent.com/u/218163569?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-26T12:21:23Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52575805285', 'type': 'WatchEvent', 'actor': {'id': 86885486, 'login': 'engvictorfarias', 'display_login': 'engvictorfarias', 'gravatar_id': '', 'url': 'https://api.github.com/users/engvictorfarias', 'avatar_url': 'https://avatars.githubusercontent.com/u/86885486?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-26T12:19:36Z', 'org': {'id': ...
# [{'id': '52497759395', 'type': 'ForkEvent', 'actor': {'id': 84364288, 'login': 'johndave74', 'display_login': 'johndave74', 'gravatar_id': '', 'url': 'https://api.github.com/users/johndave74', 'avatar_url': 'https://avatars.githubusercontent.com/u/84364288?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1025576031, 'node_id': 'R_kgDOPSEMXw', 'name': 'data-engineering-zoomcamp', 'full_name': 'johndave74/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'johndave74', 'id': 84364288, 'node_id': 'MDQ6VXNlcjg0MzY0Mjg4', 'avatar_url': 'https://avatars.githubusercontent.com/u/84364288?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/johndave74', 'html_url': 'https://github.com/johndave74', 'followers_url': 'https://api.github.com/users/johndave74/followers', 'following_url': 'https://api.github.com/users/johndave74/following{/other_user}', 'gists_url': 'https://api.github.com/users/johndave74/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/johndave74/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/johndave74/subscriptions', 'organizations_url': 'https://api.github.com/users/johndave74/orgs', 'repos_url': 'https://api.github.com/users/johndave74/repos', 'events_url': 'https://api.github.com/users/johndave74/events{/privacy}', 'received_events_url': 'https://api.github.com/users/johndave74/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/johndave74/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/languages', 'stargazers_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/stargazers', 'contributors_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/contributors', 'subscribers_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/subscribers', 'subscription_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/subscription', 'commits_url': 'https://api.github.com/repos/johndave74/data-engineering-zoomcamp/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/johnda ...
# [{'id': '52402234419', 'type': 'WatchEvent', 'actor': {'id': 69193384, 'login': 'tcetamitpandey', 'display_login': 'tcetamitpandey', 'gravatar_id': '', 'url': 'https://api.github.com/users/tcetamitpandey', 'avatar_url': 'https://avatars.githubusercontent.com/u/69193384?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-22T15:55:15Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52400439821', 'type': 'WatchEvent', 'actor': {'id': 182138820, 'login': 'aahamoustafa', 'display_login': 'aahamoustafa', 'gravatar_id': '', 'url': 'https://api.github.com/users/aahamoustafa', 'avatar_url': 'https://avatars.githubusercontent.com/u/182138820?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-22T15:18:07Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52395140603', 'type': 'WatchEvent', 'actor': {'id': 107579508, 'login': 'mitchellfagert', 'display_login': 'mitchellfagert', 'gravatar_id': '', 'url': 'https://api.github.com/users/mitchellfagert', 'avatar_url': 'https://avatars.githubusercontent.com/u/107579508?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-22T13:40:40Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52395101778', 'type': 'WatchEvent', 'actor': {'id': 71004836, 'login': '578869', 'display_login': '578869', 'gravatar_id': '', 'url': 'https://api.github.com/users/578869', 'avatar_url': 'https://avatars.githubusercontent.com/u/71004836?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-22T13:39:58Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52394034657', 'type': 'WatchEvent', 'actor': {'id': 55298343, 'login': 'aitkar', 'display_login': 'aitkar', 'gravatar_id': '', 'url': 'https://api.github.com/users/aitkar', 'avatar_url': 'https://avatars.githubusercontent.com/u/55298343?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-22T13:20:38Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52394017600', 'type': 'WatchEvent', 'actor': {'id': 112552314, 'login': 'IrisChen04', 'display_login': 'IrisChen04', 'gravatar_id': '', 'url': 'https://api.github.com/users/IrisChen04', 'avatar_url': 'https://avatars.githubusercontent.com/u/112552314?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-22T13:20:19Z', ' ...
# [{'id': '52325087488', 'type': 'WatchEvent', 'actor': {'id': 47296379, 'login': 'Alec-Samson', 'display_login': 'Alec-Samson', 'gravatar_id': '', 'url': 'https://api.github.com/users/Alec-Samson', 'avatar_url': 'https://avatars.githubusercontent.com/u/47296379?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-21T07:18:33Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52324121910', 'type': 'WatchEvent', 'actor': {'id': 108874533, 'login': 'amir-mukanov', 'display_login': 'amir-mukanov', 'gravatar_id': '', 'url': 'https://api.github.com/users/amir-mukanov', 'avatar_url': 'https://avatars.githubusercontent.com/u/108874533?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-21T06:50:05Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52322634265', 'type': 'ForkEvent', 'actor': {'id': 10900929, 'login': 'subbusanka', 'display_login': 'subbusanka', 'gravatar_id': '', 'url': 'https://api.github.com/users/subbusanka', 'avatar_url': 'https://avatars.githubusercontent.com/u/10900929?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1023409839, 'node_id': 'R_kgDOPP_-rw', 'name': 'data-engineering-zoomcamp', 'full_name': 'subbusanka/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'subbusanka', 'id': 10900929, 'node_id': 'MDQ6VXNlcjEwOTAwOTI5', 'avatar_url': 'https://avatars.githubusercontent.com/u/10900929?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/subbusanka', 'html_url': 'https://github.com/subbusanka', 'followers_url': 'https://api.github.com/users/subbusanka/followers', 'following_url': 'https://api.github.com/users/subbusanka/following{/other_user}', 'gists_url': 'https://api.github.com/users/subbusanka/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/subbusanka/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/subbusanka/subscriptions', 'organizations_url': 'https://api.github.com/users/subbusanka/orgs', 'repos_url': 'https://api.github.com/users/subbusanka/repos', 'events_url': 'https://api.github.com/users/subbusanka/events{/privacy}', 'received_events_url': 'https://api.github.com/users/subbusanka/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/subbusanka/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/subbusanka/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/subbusanka/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/subbusanka/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/subbusanka/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/subbusanka/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/subbusanka/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/subbusanka/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/subbusanka/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github ...
# [{'id': '52296837570', 'type': 'WatchEvent', 'actor': {'id': 11745334, 'login': 'jeancarlox43', 'display_login': 'jeancarlox43', 'gravatar_id': '', 'url': 'https://api.github.com/users/jeancarlox43', 'avatar_url': 'https://avatars.githubusercontent.com/u/11745334?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-19T21:07:25Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52295503530', 'type': 'WatchEvent', 'actor': {'id': 86009099, 'login': 'Ictland', 'display_login': 'Ictland', 'gravatar_id': '', 'url': 'https://api.github.com/users/Ictland', 'avatar_url': 'https://avatars.githubusercontent.com/u/86009099?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-19T19:09:56Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52295493709', 'type': 'WatchEvent', 'actor': {'id': 113074116, 'login': 'Hwangbot', 'display_login': 'Hwangbot', 'gravatar_id': '', 'url': 'https://api.github.com/users/Hwangbot', 'avatar_url': 'https://avatars.githubusercontent.com/u/113074116?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-19T19:09:10Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52293650190', 'type': 'ForkEvent', 'actor': {'id': 52947378, 'login': 'khushil-sketch', 'display_login': 'khushil-sketch', 'gravatar_id': '', 'url': 'https://api.github.com/users/khushil-sketch', 'avatar_url': 'https://avatars.githubusercontent.com/u/52947378?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1022706257, 'node_id': 'R_kgDOPPVCUQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'khushil-sketch/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'khushil-sketch', 'id': 52947378, 'node_id': 'MDQ6VXNlcjUyOTQ3Mzc4', 'avatar_url': 'https://avatars.githubusercontent.com/u/52947378?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/khushil-sketch', 'html_url': 'https://github.com/khushil-sketch', 'followers_url': 'https://api.github.com/users/khushil-sketch/followers', 'following_url': 'https://api.github.com/users/khushil-sketch/following{/other_user}', 'gists_url': 'https://api.github.com/users/khushil-sketch/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/khushil-sketch/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/khushil-sketch/subscriptions', 'organizations_url': 'https://api.github.com/users/khushil-sketch/orgs', 'repos_url': 'https://api.github.com/users/khushil-sketch/repos', 'events_url': 'https://api.github.com/users/khushil-sketch/events{/privacy}', 'received_events_url': 'https://api.github.com/users/khushil-sketch/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/khushil-sketch/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/khushil-s ...
# [{'id': '52272665236', 'type': 'WatchEvent', 'actor': {'id': 150363098, 'login': 'hafsaChoudhari16', 'display_login': 'hafsaChoudhari16', 'gravatar_id': '', 'url': 'https://api.github.com/users/hafsaChoudhari16', 'avatar_url': 'https://avatars.githubusercontent.com/u/150363098?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-18T18:17:25Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52272366086', 'type': 'WatchEvent', 'actor': {'id': 6624092, 'login': 'lilitbaghunts', 'display_login': 'lilitbaghunts', 'gravatar_id': '', 'url': 'https://api.github.com/users/lilitbaghunts', 'avatar_url': 'https://avatars.githubusercontent.com/u/6624092?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-18T18:08:35Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52271178949', 'type': 'WatchEvent', 'actor': {'id': 25465344, 'login': 'filipenkovad', 'display_login': 'filipenkovad', 'gravatar_id': '', 'url': 'https://api.github.com/users/filipenkovad', 'avatar_url': 'https://avatars.githubusercontent.com/u/25465344?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-18T17:33:42Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52270114904', 'type': 'WatchEvent', 'actor': {'id': 163501857, 'login': 'harshindcoder', 'display_login': 'harshindcoder', 'gravatar_id': '', 'url': 'https://api.github.com/users/harshindcoder', 'avatar_url': 'https://avatars.githubusercontent.com/u/163501857?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-18T17:02:45Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52265343580', 'type': 'WatchEvent', 'actor': {'id': 64129, 'login': 'xmonader', 'display_login': 'xmonader', 'gravatar_id': '', 'url': 'https://api.github.com/users/xmonader', 'avatar_url': 'https://avatars.githubusercontent.com/u/64129?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-18T14:58:49Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52259414612', 'type': 'ForkEvent', 'actor': {'id': 132018920, 'login': 'MazenGhanem', 'display_login': 'MazenGhanem', 'gravatar_id': '', 'url': 'https://api.github.com/users/MazenGhanem', 'avatar_url': 'https://avatars.githubusercontent.com/u/132018920?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1022091845, 'node_id': 'R_kgDOPOviRQ ...
# [{'id': '52179036680', 'type': 'ForkEvent', 'actor': {'id': 198799600, 'login': 'justDlabguy', 'display_login': 'justDlabguy', 'gravatar_id': '', 'url': 'https://api.github.com/users/justDlabguy', 'avatar_url': 'https://avatars.githubusercontent.com/u/198799600?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1021066692, 'node_id': 'R_kgDOPNw9xA', 'name': 'Learn-data-engineering', 'full_name': 'justDlabguy/Learn-data-engineering', 'private': False, 'owner': {'login': 'justDlabguy', 'id': 198799600, 'node_id': 'U_kgDOC9lw8A', 'avatar_url': 'https://avatars.githubusercontent.com/u/198799600?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/justDlabguy', 'html_url': 'https://github.com/justDlabguy', 'followers_url': 'https://api.github.com/users/justDlabguy/followers', 'following_url': 'https://api.github.com/users/justDlabguy/following{/other_user}', 'gists_url': 'https://api.github.com/users/justDlabguy/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/justDlabguy/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/justDlabguy/subscriptions', 'organizations_url': 'https://api.github.com/users/justDlabguy/orgs', 'repos_url': 'https://api.github.com/users/justDlabguy/repos', 'events_url': 'https://api.github.com/users/justDlabguy/events{/privacy}', 'received_events_url': 'https://api.github.com/users/justDlabguy/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/justDlabguy/Learn-data-engineering', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering', 'forks_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/forks', 'keys_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/teams', 'hooks_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/hooks', 'issue_events_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/issues/events{/number}', 'events_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/events', 'assignees_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/assignees{/user}', 'branches_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/branches{/branch}', 'tags_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/tags', 'blobs_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/languages', 'stargazers_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/stargazers', 'contributors_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/contributors', 'subscribers_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/subscribers', 'subscription_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/subscription', 'commits_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/justDlabguy/Learn-data-engineering/git/commits ...
# [{'id': '52123619539', 'type': 'WatchEvent', 'actor': {'id': 117845465, 'login': 'Scottymichaelmillerguy', 'display_login': 'Scottymichaelmillerguy', 'gravatar_id': '', 'url': 'https://api.github.com/users/Scottymichaelmillerguy', 'avatar_url': 'https://avatars.githubusercontent.com/u/117845465?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-15T18:43:21Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52123088600', 'type': 'WatchEvent', 'actor': {'id': 220941820, 'login': 'RJ-DataHacks', 'display_login': 'RJ-DataHacks', 'gravatar_id': '', 'url': 'https://api.github.com/users/RJ-DataHacks', 'avatar_url': 'https://avatars.githubusercontent.com/u/220941820?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-15T18:29:06Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52122903736', 'type': 'WatchEvent', 'actor': {'id': 199794236, 'login': 'Christy-Program', 'display_login': 'Christy-Program', 'gravatar_id': '', 'url': 'https://api.github.com/users/Christy-Program', 'avatar_url': 'https://avatars.githubusercontent.com/u/199794236?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-15T18:24:16Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52097424577', 'type': 'WatchEvent', 'actor': {'id': 102948498, 'login': 'MaLrc', 'display_login': 'MaLrc', 'gravatar_id': '', 'url': 'https://api.github.com/users/MaLrc', 'avatar_url': 'https://avatars.githubusercontent.com/u/102948498?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-15T09:09:39Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52094034790', 'type': 'WatchEvent', 'actor': {'id': 38570624, 'login': 'RandSaleh', 'display_login': 'RandSaleh', 'gravatar_id': '', 'url': 'https://api.github.com/users/RandSaleh', 'avatar_url': 'https://avatars.githubusercontent.com/u/38570624?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-15T07:55:37Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52093676314', 'type': 'WatchEvent', 'actor': {'id': 56254171, 'login': 'PetrJoe', 'display_login': 'PetrJoe', 'gravatar_id': '', 'url': 'https://api.github.com/users/PetrJoe', 'avatar_url': 'https://avatars.githubusercontent.com/u/56254171?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': ...
# [{'id': '52040127738', 'type': 'WatchEvent', 'actor': {'id': 173776489, 'login': 'LoneMusashi', 'display_login': 'LoneMusashi', 'gravatar_id': '', 'url': 'https://api.github.com/users/LoneMusashi', 'avatar_url': 'https://avatars.githubusercontent.com/u/173776489?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-14T06:37:48Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52036538730', 'type': 'WatchEvent', 'actor': {'id': 43141076, 'login': 'yankunsong', 'display_login': 'yankunsong', 'gravatar_id': '', 'url': 'https://api.github.com/users/yankunsong', 'avatar_url': 'https://avatars.githubusercontent.com/u/43141076?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-14T04:24:54Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52029959989', 'type': 'WatchEvent', 'actor': {'id': 102864198, 'login': 'MustafaKpn', 'display_login': 'MustafaKpn', 'gravatar_id': '', 'url': 'https://api.github.com/users/MustafaKpn', 'avatar_url': 'https://avatars.githubusercontent.com/u/102864198?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-13T21:51:35Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52029395646', 'type': 'WatchEvent', 'actor': {'id': 189120651, 'login': 'PYcrypto666', 'display_login': 'PYcrypto666', 'gravatar_id': '', 'url': 'https://api.github.com/users/PYcrypto666', 'avatar_url': 'https://avatars.githubusercontent.com/u/189120651?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-13T21:03:01Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52028328598', 'type': 'WatchEvent', 'actor': {'id': 61951032, 'login': 'fyoalharbi', 'display_login': 'fyoalharbi', 'gravatar_id': '', 'url': 'https://api.github.com/users/fyoalharbi', 'avatar_url': 'https://avatars.githubusercontent.com/u/61951032?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-13T19:33:36Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52026587240', 'type': 'WatchEvent', 'actor': {'id': 111182377, 'login': 'JoanData', 'display_login': 'JoanData', 'gravatar_id': '', 'url': 'https://api.github.com/users/JoanData', 'avatar_url': 'https://avatars.githubusercontent.com/u/111182377?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-13T17:19:55Z', 'org' ...

# %%
# normalization example
event = events_page[0]
event
# Out:
# {'id': '52040127738',
#  'type': 'WatchEvent',
#  'actor': {'id': 173776489,
#   'login': 'LoneMusashi',
#   'display_login': 'LoneMusashi',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/LoneMusashi',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/173776489?'},
#  'repo': {'id': 419661684,
#   'name': 'DataTalksClub/data-engineering-zoomcamp',
#   'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#  'payload': {'action': 'started'},
#  'public': True,
#  'created_at': '2025-07-14T06:37:48Z',
#  'org': {'id': 72699292,
#   'login': 'DataTalksClub',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/orgs/DataTalksClub',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}

# %%
def process_event(event):
    result = {}

    result['id'] = event['id']
    result['type'] = event['type']
    result['public'] = event['public']
    result['created_at'] = event['created_at']

    result['actor__id'] = event['actor']['id']
    result['actor__login'] = event['actor']['login']

    return result

# %%
processed_events = [] # Initialize an empty list to store processed events

# Process each event in the current page
for event in events_page:
    processed_events.append(process_event(event))  # Append the processed event to the list

processed_events
# Out:
# [{'id': '52040127738',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-14T06:37:48Z',
#   'actor__id': 173776489,
#   'actor__login': 'LoneMusashi'},
#  {'id': '52036538730',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-14T04:24:54Z',
#   'actor__id': 43141076,
#   'actor__login': 'yankunsong'},
#  {'id': '52029959989',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T21:51:35Z',
#   'actor__id': 102864198,
#   'actor__login': 'MustafaKpn'},
#  {'id': '52029395646',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T21:03:01Z',
#   'actor__id': 189120651,
#   'actor__login': 'PYcrypto666'},
#  {'id': '52028328598',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T19:33:36Z',
#   'actor__id': 61951032,
#   'actor__login': 'fyoalharbi'},
#  {'id': '52026587240',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T17:19:55Z',
#   'actor__id': 111182377,
#   'actor__login': 'JoanData'},
#  {'id': '52026343824',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T17:01:46Z',
#   'actor__id': 96800487,
#   'actor__login': 'Pier1501'},
#  {'id': '52025860710',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T16:25:30Z',
#   'actor__id': 127719622,
#   'actor__login': 'cranidos12'},
#  {'id': '52024659703',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T14:59:56Z',
#   'actor__id': 60624133,
#   'actor__login': 'ten-jampa'},
#  {'id': '52024425942',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T14:43:12Z',
#   'actor__id': 58373200,
#   'actor__login': 'tharrmeehan'},
#  {'id': '52023774253',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-13T13:58:40Z',
#   'actor__id': 196545460,
#   'actor__login': 'ThoTruongTran'},
#  {'id': '52023438439',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T13:33:18Z',
#   'actor__id': 79533562,
#   'actor__login': 'akshayskumar94'},
#  {'id': '52023065804',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T13:07:18Z',
#   'actor__id': 163012286,
#   'actor__login': 'u3mukher'},
#  {'id': '52022346322',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T12:17:17Z',
#   'actor__id': 175994506,
#   'actor__login': 'jpdas27'},
#  {'id': '52021125901',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-13T10:42:10Z',
#   'actor__id': 103904727,
#   'actor__login': 'mtrawczynski'},
#  {'id': '52020625024',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-13T10:04:58Z',
#   'actor__id': 71553115,
#   'actor__login': 'Ola-20'},
#  {'id': '52019773294',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-13T08:59:15Z',
#   'actor__id': 163404418,
#   'actor__login': 'gadev41'},
#  {'id': '52019320679',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T08:20:42Z',
#   'actor__id': 106782525,
#   'actor__login': 'eferikli'},
#  {'id': '52019290156',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T08:18:06Z',
#   'actor__id': 88800929,
#   'actor__login': 'annalach'},
#  {'id': '52018281700',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-13T06:50:26Z',
#   'actor__id': 55611409,
#   'actor__login': 'dansli'},
#  {'id': '52018264035',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T06:48:50Z',
#   'actor__id': 147181495,
#   'actor__login': 'Ayushbhusari22'},
#  {'id': '52016619932',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-13T04:03:55Z',
#   'actor__id': 108572138,
#   'actor__login': 'bharadvaj19'},
#  {'id': '52016618012',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T04:03:43Z',
#   'actor__id': 108572138,
#   'actor__login': 'bharadvaj19'},
#  {'id': '52015773236',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-13T02:39:12Z',
#   'actor__id': 59468959,
#   'actor__login': 'Jackiewwuu'},
#  {'id': '52015319178',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T01:51:37Z',
#   'actor__id': 48914402,
#   'actor__login': 'Milagros-cucu'},
#  {'id': '52015139443',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T01:32:36Z',
#   'actor__id': 183396059,
#   'actor__login': 'maykonlincolnusa'},
#  {'id': '52014996769',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-13T01:17:15Z',
#   'actor__id': 170357317,
#   'actor__login': 'BrunoChiconato'}]

# %%
from datetime import datetime

def process_event(event):
    result = {}

    result['id'] = event['id']
    result['type'] = event['type']
    result['public'] = event['public']

    parsed_timestamp = datetime.strptime(event['created_at'], '%Y-%m-%dT%H:%M:%SZ')
    result['created_at'] = parsed_timestamp.timestamp() # Convert to timestamp

    result['actor__login'] = event['actor']['login']

    return result

process_event(event)
# Out:
# {'id': '52014996769',
#  'type': 'WatchEvent',
#  'public': True,
#  'created_at': 1752358635.0,
#  'actor__login': 'BrunoChiconato'}

# %%
all_data = []

pages = events_getter()

for page in pages:
    all_data.extend(page) # Extend the all_data list with the current page of events

len(all_data)  # Check the total number of events collected
# Out:
# 297

# %%
def process_event(event):
    '''
    Process a single event and extract relevant information.
    This function also extracts topics linked to the event.
    It returns a dictionary with the processed event data and a list of topics.
    '''
    result = {}

    result['id'] = event['id']
    result['type'] = event['type']
    result['public'] = event['public']

    parsed_timestamp = datetime.strptime(event['created_at'], '%Y-%m-%dT%H:%M:%SZ')
    result['created_at'] = parsed_timestamp.timestamp()  # Convert to timestamp

    result['actor__id'] = event['actor']['id']
    result['actor__login'] = event['actor']['login']

    topics = event.get('payload', {}).get('pull_request', {}).get('base', {}).get('repo', {}).get('topics', [])

    processed_topics = []
    for topic in topics:
        processed_topic = {
            'event_id': event['id'],
            'topic_name': topic,
        }
        processed_topics.append(processed_topic)

    return result, processed_topics

# %%
processed_events = []  # Initialize an empty list to store processed events
processed_topics = []  # Initialize an empty list to store processed topics

for event in all_data:
    # Process each event and extract topics linked to the event
    processed_event, topics = process_event(event)
    processed_events.append(processed_event)  # Append the processed event to the list
    processed_topics.extend(topics)  # Extend the processed_topics list with the current event's topics

print(processed_events[:5]) # Print the first 5 processed events to verify
print(processed_topics[:5]) # Print the processed topics to verify
# Out:
# [{'id': '52602815580', 'type': 'WatchEvent', 'public': True, 'created_at': 1753652176.0, 'actor__id': 66147771, 'actor__login': 'HephWisdom', 'repo__id': 419661684}, {'id': '52601462680', 'type': 'ForkEvent', 'public': True, 'created_at': 1753645940.0, 'actor__id': 33403958, 'actor__login': 'singh3ss', 'repo__id': 419661684}, {'id': '52599931066', 'type': 'IssuesEvent', 'public': True, 'created_at': 1753638143.0, 'actor__id': 42957613, 'actor__login': 'SanathPatil', 'repo__id': 419661684}, {'id': '52599592886', 'type': 'ForkEvent', 'public': True, 'created_at': 1753636486.0, 'actor__id': 217340527, 'actor__login': 'KittyNiuNiu', 'repo__id': 419661684}, {'id': '52599588942', 'type': 'WatchEvent', 'public': True, 'created_at': 1753636467.0, 'actor__id': 217340527, 'actor__login': 'KittyNiuNiu', 'repo__id': 419661684}]
# [{'event_id': '52146985881', 'topic_name': 'data-engineering'}, {'event_id': '52146985881', 'topic_name': 'dbt'}, {'event_id': '52146985881', 'topic_name': 'docker'}, {'event_id': '52146985881', 'topic_name': 'kafka'}, {'event_id': '52146985881', 'topic_name': 'kestra'}]

# %% [markdown]
# ##### Loading Data

# %%
# Using DuckDB script that creates two separate tables
# 1. watch_events -> Stores WatchEvent data
# 2. pull_request_events -> Stores PullRequestEvent data
# 
# A basic pipeline requires:
# 1. Setting up a database connection
# 2. Creating tables and defining schemas
# 3. Writing queries to insert/update data
# 4. Handling schema changes manually

# %%
import duckdb

# 1. create a connection to a DuckDB database
conn = duckdb.connect('github_events.db')

# %%
processed_events[0]
# Out:
# {'id': '52602815580',
#  'type': 'WatchEvent',
#  'public': True,
#  'created_at': 1753652176.0,
#  'actor__id': 66147771,
#  'actor__login': 'HephWisdom'}

# %%
# 2. Create the `github_events` table
conn.execute("""
CREATE TABLE IF NOT EXISTS github_events (
    id TEXT PRIMARY KEY,
    type TEXT,
    public BOOLEAN,
    created_at DOUBLE,
    actor__id BIGINT,
    actor__login TEXT
);
""")

# %%
flattened_data = [
    (
        record['id'],
        record['type'],
        record['public'],
        record['created_at'],
        record['actor__id'],
        record['actor__login']
    )
    for record in processed_events
]

# 3. Insert the processed events into the `github_events` table
conn.executemany("""
INSERT INTO github_events (id, type, public, created_at, actor__id, actor__login)
VALUES (?, ?, ?, ?, ?, ?)
ON CONFLICT (id) DO NOTHING;
""", flattened_data)

# %%
df = conn.execute("SELECT * FROM github_events").df()
df.head()
# Out:
#             id        type  public    created_at  actor__id  actor__login
# 0  52597550818  WatchEvent    True  1.753627e+09  223146409  stanlech1922
# 1  52597445530  WatchEvent    True  1.753627e+09  131308557    stanlech97
# 2  52596512513  WatchEvent    True  1.753623e+09   48296646     jia-jiang
# 3  52594624618  WatchEvent    True  1.753615e+09     759158     cleonildo
# 4  52594229027  WatchEvent    True  1.753613e+09  107476202  Augustus2011

# %%
conn.close()  # Close the connection when done

# %% [markdown]
# #### Dynamic Schema Handling

# %%
def process_event(event):
    '''
    Process a single event and extract relevant information.
    This function also extracts topics linked to the event.
    It returns a dictionary with the processed event data and a list of topics.
    '''
    result = {}

    result['id'] = event['id']
    result['type'] = event['type']
    result['public'] = event['public']

    parsed_timestamp = datetime.strptime(event['created_at'], '%Y-%m-%dT%H:%M:%SZ')
    result['created_at'] = parsed_timestamp.timestamp()  # Convert to timestamp

    result['actor__id'] = event['actor']['id']
    result['actor__login'] = event['actor']['login']

    result['repo__id'] = event['repo']['id'] # Extract repository ID

    topics = event.get('payload', {}).get('pull_request', {}).get('base', {}).get('repo', {}).get('topics', [])

    processed_topics = []
    for topic in topics:
        processed_topic = {
            'event_id': event['id'],
            'topic_name': topic,
        }
        processed_topics.append(processed_topic)

    return result, processed_topics

# %%
processed_events = []  # Initialize an empty list to store processed events
processed_topics = []  # Initialize an empty list to store processed topics

for event in all_data:
    # Process each event and extract topics linked to the event
    processed_event, topics = process_event(event)
    processed_events.append(processed_event)  # Append the processed event to the list
    processed_topics.extend(topics)  # Extend the processed_topics list with the current event's topics

print(processed_events[:5]) # Print the first 5 processed events to verify
print(processed_topics[:5]) # Print the processed topics to verify
# Out:
# [{'id': '52602815580', 'type': 'WatchEvent', 'public': True, 'created_at': 1753652176.0, 'actor__id': 66147771, 'actor__login': 'HephWisdom', 'repo__id': 419661684}, {'id': '52601462680', 'type': 'ForkEvent', 'public': True, 'created_at': 1753645940.0, 'actor__id': 33403958, 'actor__login': 'singh3ss', 'repo__id': 419661684}, {'id': '52599931066', 'type': 'IssuesEvent', 'public': True, 'created_at': 1753638143.0, 'actor__id': 42957613, 'actor__login': 'SanathPatil', 'repo__id': 419661684}, {'id': '52599592886', 'type': 'ForkEvent', 'public': True, 'created_at': 1753636486.0, 'actor__id': 217340527, 'actor__login': 'KittyNiuNiu', 'repo__id': 419661684}, {'id': '52599588942', 'type': 'WatchEvent', 'public': True, 'created_at': 1753636467.0, 'actor__id': 217340527, 'actor__login': 'KittyNiuNiu', 'repo__id': 419661684}]
# [{'event_id': '52146985881', 'topic_name': 'data-engineering'}, {'event_id': '52146985881', 'topic_name': 'dbt'}, {'event_id': '52146985881', 'topic_name': 'docker'}, {'event_id': '52146985881', 'topic_name': 'kafka'}, {'event_id': '52146985881', 'topic_name': 'kestra'}]

# %%
# Create connection to DuckDB
conn = duckdb.connect('github_events.db')

# %%
current_columns = {row[1] for row in conn.execute("PRAGMA table_info(github_events)").fetchall()}
print("Current columns in github_events table:", current_columns)
# Out:
# Current columns in github_events table: {'created_at', 'actor__id', 'actor__login', 'type', 'public', 'id'}

# %%
# 3. Detect and add new columns dynamically
for record in processed_events[10:]:
    for key in record.keys():
        if key not in current_columns:
            col_type = 'TEXT'  # Default type for new columns
            if isinstance(record[key], bool):
                col_type = 'BOOLEAN'
            elif isinstance(record[key], int):
                col_type = 'BIGINT'
            elif isinstance(record[key], float):
                col_type = 'DOUBLE'
            print(f'ALTER TABLE github_events ADD COLUMN {key} {col_type};')
            alter_query = f"ALTER TABLE github_events ADD COLUMN {key} {col_type};"
            conn.execute(alter_query)
            print(f"Added new column: {key} with type {col_type}")
            current_columns.add(key) # Update schema tracking
# Out:
# ALTER TABLE github_events ADD COLUMN repo__id BIGINT;
# Added new column: repo__id with type BIGINT

# %%
# 4. Prepare data for insertion (handle missing fields)
columns = sorted(current_columns) # Maintain consistent order
flattened_data = [
    tuple(record.get(col, None) for col in columns)  # # fill missing values wwith NULL
    for record in processed_events
]

# 5. Construct dynamic SQL for insertion
placeholders = ', '.join(['?' for _ in columns])  # Create placeholders for each column
columns_str = ', '.join(columns)  # Create a comma-separated string of column names

insert_query = f"""
INSERT INTO github_events ({columns_str})
VALUES ({placeholders})
ON CONFLICT (id) DO UPDATE SET {", ".join([f"{col}=excluded.{col}" for col in columns if col != 'id'])};
"""

# %%
conn.executemany(insert_query, flattened_data)

# %%
df = conn.execute("SELECT * FROM github_events").df()
df.head()
# Out:
#             id        type  public    created_at  actor__id  actor__login  \
# 0  52597550818  WatchEvent    True  1.753627e+09  223146409  stanlech1922
# 1  52597445530  WatchEvent    True  1.753627e+09  131308557    stanlech97
# 2  52596512513  WatchEvent    True  1.753623e+09   48296646     jia-jiang
# 3  52594624618  WatchEvent    True  1.753615e+09     759158     cleonildo
# 4  52594229027  WatchEvent    True  1.753613e+09  107476202  Augustus2011
#
#     repo__id
# 0  419661684
# 1  419661684
# 2  419661684
# 3  419661684
# 4  419661684
